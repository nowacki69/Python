# %%
import requests
from bs4 import BeautifulSoup

# %%
# with open(r"C:\Users\333051\Documents\Udemy\Python Mega Course\app7-webscraping\website\RockSprings.html", 'r') as file:
#     r = file.read()

# %%
l=[]

base_url="http://www.pyclass.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s="
for page in range(0,30,10):
    r = requests.get(base_url + str(page) + ".html", headers={'User-agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:61.0) Gecko/20100101 Firefox/61.0'})
    print(base_url + str(page) + ".html")
    c = r.content
    soup = BeautifulSoup(c, "html.parser")
    all = soup.find_all("div", {"class":"propertyRow"})

    for item in all:
        d = {}
        d["Price"] = item.find("h4", {"class":"propPrice"}).text.replace("\n", "").replace(" ", "")
        d["Addresss"] = item.find_all("span", {"class":"propAddressCollapse"})[0].text
        d["Locality"] = item.find_all("span", {"class":"propAddressCollapse"})[1].text

        try:
            d["Beds"] = item.find("span", {"class":"infoBed"}).find("b").text
        except:
            d["Beds"] = None

        try:
            d["Full Baths"] = item.find("span", {"class":"infoValueFullBath"}).find("b").text
        except:
            d["Full Baths"] = None

        try:
            d["Half Baths"] = item.find("span", {"class":"infoValueHalfBath"}).find("b").text
        except:
            d["Half Baths"] = None

        try:
            d["Sq Ftg"] = item.find("span", {"class":"infoSqFt"}).find("b").text
        except:
            d["Sq Ftg"] = None

        try:
            for column_group in item.find_all("div", {"class":"columnGroup"}):
                for feature_group, feature_name in zip(column_group.find_all("span", {"class","featureGroup"}), column_group.find_all("span", {"class":"featureName"})):
                    if "Lot Size" in feature_group.text:
                        d["Lot Size"] = feature_name.text
        except:
            d["Lot Size"] = None

        l.append(d)
# Out:
# http://www.pyclass.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s=0.html
# http://www.pyclass.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s=10.html
# http://www.pyclass.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s=20.html

# %%
l
# Out:
# [{'Price': '$725,000',
#   'Addresss': '0 Gateway',
#   'Locality': 'Rock Springs, WY 82901',
#   'Beds': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Sq Ftg': None},
#  {'Price': '$452,900',
#   'Addresss': '1003 Winchester Blvd.',
#   'Locality': 'Rock Springs, WY 82901',
#   'Beds': '4',
#   'Full Baths': '4',
#   'Half Baths': None,
#   'Sq Ftg': None,
#   'Lot Size': '0.21 Acres'},
#  {'Price': '$396,900',
#   'Addresss': '600 Talladega',
#   'Locality': 'Rock Springs, WY 82901',
#   'Beds': '5',
#   'Full Baths': '3',
#   'Half Baths': None,
#   'Sq Ftg': '3,154'},
#  {'Price': '$389,900',
#   'Addresss': '3239 Spearhead Way',
#   'Locality': 'Rock Springs, WY 82901',
#   'Beds': '4',
#   'Full Baths': '3',
#   'Half Baths': '1',
#   'Sq Ftg': '3,076',
#   'Lot Size': 'Under 1/2 Acre, '},
#  {'Price': '$254,000',
#   'Addresss': '522 Emerald Street',
#   'Locality': 'Rock Springs, WY 82901',
#   'Beds': '3',
#   'Full Baths': '3',
#   'Half Baths': None,
#   'Sq Ftg': '1,172',
#   'Lot Size': 'Under 1/2 Acre, '},
#  {'Price': '$252,900',
#   'Addresss': "1302 Veteran's Drive",
#   'Locality': 'Rock Springs, WY 82901',
#   'Beds': '4',
#   'Full Baths': '2',
#   'Half Baths': None,
#   'Sq Ftg': '1,932',
#   'Lot Size': '0.27 Acres'},
#  {'Price': '$210,000',
#   'Addresss': '1021 Cypress Cir',
#   'Locality': 'Rock Springs, WY 82901',
#   'Beds': '4',
#   'Full Baths': '3',
#   'Half Baths': None,
#   'Sq Ftg': '1,676',
#   'Lot Size': 'Under 1/2 Acre, '},
#  {'Price': '$209,000',
#   'Addresss': '913 Madison Dr',
#   'Locality': 'Rock Springs, WY 82901',
#   'Beds': '3',
#   'Full Baths': '2',
#   'Half Baths': None,
#   'Sq Ftg': '1,344',
#   'Lot Size': 'Under 1/2 Acre, '},
#  {'Price': '$199,900',
#   'Addresss': '1344 Teton Street',
#   'Locality': 'Rock Springs, WY 82901',
#   'Beds': '3',
#   'Full Baths': '2',
#   'Half Baths': None,
#   'Sq Ftg': '1,920',
#   'Lot Size': 'Under 1/2 Acre, '},
#  {'Price': '$196,900',
#   'Addresss': '4 Minnies Lane',
#   'Locality': 'Rock Springs, WY 82901',
#   'Beds': '3',
#   'Full Baths': '2',
#   'Half Baths': None,
#   'Sq Ftg': '1,664',
#   'Lot Size': '2.02 Acres'},
#  {'Price': '$1,700,000',
#   'Addresss': '9339 Sd 26900',
#   'Locality': 'Rocksprings, TX 78880',
#   'Beds': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Sq Ftg': '2,560'},
#  {'Price': '$1,100,000',
#   'Addresss': 'RR674P13 Hwy 377',
#   'Locality': 'Rocksprings, TX 78880',
#   'Beds': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Sq Ftg': '2,000'},
#  {'Price': '$1,080,000',
#   'Addresss': '0 Hwy 41',
#   'Locality': 'Rocksprings, TX 78880',
#   'Beds': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Sq Ftg': None},
#  {'Price': '$908,350',
#   'Addresss': '9339 Sd 26900',
#   'Locality': 'Rocksprings, TX 78880',
#   'Beds': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Sq Ftg': '2,560'},
#  {'Price': '$905,000',
#   'Addresss': 'CR450 Hwy 377',
#   'Locality': 'Rocksprings, TX 78880',
#   'Beds': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Sq Ftg': None},
#  {'Price': '$695,000',
#   'Addresss': 'Cr 240 Cr 240',
#   'Locality': 'Rocksprings, TX 78880',
#   'Beds': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Sq Ftg': '1,398'},
#  {'Price': '$605,000',
#   'Addresss': 'RR674 Hwy 377',
#   'Locality': 'Rocksprings, TX 78880',
#   'Beds': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Sq Ftg': '1,738'},
#  {'Price': '$559,805',
#   'Addresss': '9770a Sd 26900',
#   'Locality': 'Rocksprings, TX 78880',
#   'Beds': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Sq Ftg': '1,080'},
#  {'Price': '$504,000',
#   'Addresss': 'Lot17 CR 2630',
#   'Locality': 'Rocksprings, TX 78880',
#   'Beds': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Sq Ftg': None},
#  {'Price': '$410,000',
#   'Addresss': 'Tr12,16 CR 520',
#   'Locality': 'Rocksprings, TX 78880',
#   'Beds': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Sq Ftg': None},
#  {'Price': '$299,900',
#   'Addresss': '32575 S Shadow Mountain Road',
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Beds': '3',
#   'Full Baths': '2',
#   'Half Baths': None,
#   'Sq Ftg': '2,318'},
#  {'Price': '$167,500',
#   'Addresss': '32750 S Shangrila Drive',
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Beds': '3',
#   'Full Baths': '2',
#   'Half Baths': None,
#   'Sq Ftg': '2,120'},
#  {'Price': '$150,000',
#   'Addresss': '0000 Black Canyon Highway',
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Beds': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Sq Ftg': None,
#   'Lot Size': '5 Acres'},
#  {'Price': '$129,500',
#   'Addresss': '34775 S CHOLLA Drive',
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Beds': '3',
#   'Full Baths': '2',
#   'Half Baths': None,
#   'Sq Ftg': '1,220'},
#  {'Price': '$129,000',
#   'Addresss': '33403 S. HA-WA-SI TERRACE',
#   'Locality': 'BLACK CANYON CITY, AZ 85324',
#   'Beds': '4',
#   'Full Baths': '2',
#   'Half Baths': None,
#   'Sq Ftg': '2,000'},
#  {'Price': '$80,000',
#   'Addresss': '34263 S Bertha Street',
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Beds': '5',
#   'Full Baths': '2',
#   'Half Baths': None,
#   'Sq Ftg': '2,260'},
#  {'Price': '$77,900',
#   'Addresss': '33160 S Canyon Road',
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Beds': '3',
#   'Full Baths': '2',
#   'Half Baths': None,
#   'Sq Ftg': '1,248'},
#  {'Price': '$70,500',
#   'Addresss': '19421 E Todd Evans Road',
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Beds': '3',
#   'Full Baths': '2',
#   'Half Baths': None,
#   'Sq Ftg': '1,404'},
#  {'Price': '$70,000',
#   'Addresss': '18688 E AGUA Vista',
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Beds': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Sq Ftg': None,
#   'Lot Size': '0.7 Acres'},
#  {'Price': '$67,500',
#   'Addresss': '50600 N Old Black Canyon Road',
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Beds': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Sq Ftg': None,
#   'Lot Size': '3 Acres'},
#  {'Price': '$54,900',
#   'Addresss': '20101 E SQUAW VALLEY Road',
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Beds': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Sq Ftg': None},
#  {'Price': '$45,600',
#   'Addresss': '33259 S Canyon Road',
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Beds': '3',
#   'Full Baths': '1',
#   'Half Baths': None,
#   'Sq Ftg': '1,056'},
#  {'Price': '$40,000',
#   'Addresss': '34558 S ROADRUNNER RD',
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Beds': '2',
#   'Full Baths': '1',
#   'Half Baths': None,
#   'Sq Ftg': '784',
#   'Lot Size': 'Under 1/2 Acre'},
#  {'Price': '$30,000',
#   'Addresss': '19260 E Scenic Loop Road',
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Beds': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Sq Ftg': None,
#   'Lot Size': '2.35 Acres'},
#  {'Price': '$29,000',
#   'Addresss': '19000 E MAREN Avenue',
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Beds': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Sq Ftg': None,
#   'Lot Size': '2.05 Acres'},
#  {'Price': '$28,995',
#   'Addresss': '19350 E SAGUARO Drive',
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Beds': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Sq Ftg': None,
#   'Lot Size': '0.73 Acres'},
#  {'Price': '$15,000',
#   'Addresss': '20650 E Amethyst Place',
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Beds': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Sq Ftg': None,
#   'Lot Size': '0.31 Acres'}]

# %%
import pandas
df = pandas.DataFrame(l)
df
# Out:
#                          Addresss  Beds Full Baths Half Baths  \
# 0                       0 Gateway  None       None       None
# 1           1003 Winchester Blvd.     4          4       None
# 2                   600 Talladega     5          3       None
# 3              3239 Spearhead Way     4          3          1
# 4              522 Emerald Street     3          3       None
# 5            1302 Veteran's Drive     4          2       None
# 6                1021 Cypress Cir     4          3       None
# 7                  913 Madison Dr     3          2       None
# 8               1344 Teton Street     3          2       None
# 9                  4 Minnies Lane     3          2       None
# 10                  9339 Sd 26900  None       None       None
# 11               RR674P13 Hwy 377  None       None       None
# 12                       0 Hwy 41  None       None       None
# 13                  9339 Sd 26900  None       None       None
# 14                  CR450 Hwy 377  None       None       None
# 15                  Cr 240 Cr 240  None       None       None
# 16                  RR674 Hwy 377  None       None       None
# 17                 9770a Sd 26900  None       None       None
# 18                  Lot17 CR 2630  None       None       None
# 19                 Tr12,16 CR 520  None       None       None
# 20   32575 S Shadow Mountain Road     3          2       None
# 21        32750 S Shangrila Drive     3          2       None
# 22      0000 Black Canyon Highway  None       None       None
# 23           34775 S CHOLLA Drive     3          2       None
# 24      33403 S. HA-WA-SI TERRACE     4          2       None
# 25          34263 S Bertha Street     5          2       None
# 26            33160 S Canyon Road     3          2       None
# 27        19421 E Todd Evans Road     3          2       None
# 28             18688 E AGUA Vista  None       None       None
# 29  50600 N Old Black Canyon Road  None       None       None
# 30      20101 E SQUAW VALLEY Road  None       None       None
# 31            33259 S Canyon Road     3          1       None
# 32          34558 S ROADRUNNER RD     2          1       None
# 33       19260 E Scenic Loop Road  None       None       None
# 34           19000 E MAREN Avenue  None       None       None
# 35          19350 E SAGUARO Drive  None       None       None
# 36         20650 E Amethyst Place  None       None       None
#
#                        Locality          Lot Size       Price Sq Ftg
# 0        Rock Springs, WY 82901               NaN    $725,000   None
# 1        Rock Springs, WY 82901        0.21 Acres    $452,900   None
# 2        Rock Springs, WY 82901               NaN    $396,900  3,154
# 3        Rock Springs, WY 82901  Under 1/2 Acre,     $389,900  3,076
# 4        Rock Springs, WY 82901  Under 1/2 Acre,     $254,000  1,172
# 5        Rock Springs, WY 82901        0.27 Acres    $252,900  1,932
# 6        Rock Springs, WY 82901  Under 1/2 Acre,     $210,000  1,676
# 7        Rock Springs, WY 82901  Under 1/2 Acre,     $209,000  1,344
# 8        Rock Springs, WY 82901  Under 1/2 Acre,     $199,900  1,920
# 9        Rock Springs, WY 82901        2.02 Acres    $196,900  1,664
# 10        Rocksprings, TX 78880               NaN  $1,700,000  2,560
# 11        Rocksprings, TX 78880               NaN  $1,100,000  2,000
# 12        Rocksprings, TX 78880               NaN  $1,080,000   None
# 13        Rocksprings, TX 78880               NaN    $908,350  2,560
# 14        Rocksprings, TX 78880               NaN    $905,000   None
# 15        Rocksprings, TX 78880               NaN    $695,000  1,398
# 16        Rocksprings, TX 78880               NaN    $605,000  1,738
# 17        Rocksprings, TX 78880               NaN    $559,805  1,080
# 18        Rocksprings, TX 78880               NaN    $504,000   None
# 19        Rocksprings, TX 78880               NaN    $410,000   None
# 20  Black Canyon City, AZ 85324               NaN    $299,900  2,318
# 21  Black Canyon City, AZ 85324               NaN    $167,500  2,120
# 22  Black Canyon City, AZ 85324           5 Acres    $150,000   None
# 23  Black Canyon City, AZ 85324               NaN    $129,500  1,220
# 24  BLACK CANYON CITY, AZ 85324               NaN    $129,000  2,000
# 25  Black Canyon City, AZ 85324               NaN     $80,000  2,260
# 26  Black Canyon City, AZ 85324               NaN     $77,900  1,248
# 27  Black Canyon City, AZ 85324               NaN     $70,500  1,404
# 28  Black Canyon City, AZ 85324         0.7 Acres     $70,000   None
# 29  Black Canyon City, AZ 85324           3 Acres     $67,500   None
# 30  Black Canyon City, AZ 85324               NaN     $54,900   None
# 31  Black Canyon City, AZ 85324               NaN     $45,600  1,056
# 32  Black Canyon City, AZ 85324    Under 1/2 Acre     $40,000    784
# 33  Black Canyon City, AZ 85324        2.35 Acres     $30,000   None
# 34  Black Canyon City, AZ 85324        2.05 Acres     $29,000   None
# 35  Black Canyon City, AZ 85324        0.73 Acres     $28,995   None
# 36  Black Canyon City, AZ 85324        0.31 Acres     $15,000   None

# %%
df.to_csv("Output.csv")
